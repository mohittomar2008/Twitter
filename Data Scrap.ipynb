# %%
#!pip install selenium

# %%
# import libraraies

import selenium
from selenium import webdriver
import pandas as pd

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

import warnings
warnings.filterwarnings('ignore')
import time

# %%
# lets connect to driver

driver= webdriver.Chrome(r'C:\Users\Administrator\Data Science\WebScrapping\chromedriver.exe')
driver.maximize_window()

url='https://www.olx.in/items/q-cars?isSearchCall=true'
driver.get(url)

# %%
link= driver.find_elements_by_xpath('//li[@class="EIR5N"]/a')

# %%
url=[]
for i in link:
    url.append(i.get_attribute('href'))

# %%
len(url)
# Out:
# 500

# %%
name=[]
manufacture=[]
model=[]
fuel=[]
driven=[]
automatic=[]
owner=[]
location=[]
postingdate=[]
price=[]


for i in url:
    driver.get(i)
    time.sleep(2)
    try:
        title= driver.find_element_by_class_name('_35xN1')
        name.append(title.text.split('(')[0])
        
    except NoSuchElementException:
        name.append('-')
        
    try:
        title= driver.find_element_by_class_name('_35xN1')
        manufacture.append(title.text.split('(')[1].replace(')',''))
    except NoSuchElementException:
        manufacture.append('-')
        
      
    try:
        Model=driver.find_element_by_class_name('_3tLee')
        model.append(Model.text)
    except NoSuchElementException:
        model.append('-')
    try:
        tab=driver.find_element_by_class_name('aOxkz')
        fuel.append(tab.text.split('\n')[0])
    except NoSuchElementException:
        fuel.append('-')
    try:
        tab=driver.find_element_by_class_name('aOxkz')
        driven.append(tab.text.split('\n')[1])
    except NoSuchElementException:
        driven.append('-')
    try:
        tab=driver.find_element_by_class_name('aOxkz')
        automatic.append(tab.text.split('\n')[2])
    except NoSuchElementException:
        automatic.append('-')
        
    try:
        Owner=driver.find_element_by_xpath('//div[@class="_1l939"]/div[1]/div[2]/div[2]')
        owner.append(Owner.text)
    except NoSuchElementException:
        owner.append('-')
        
    try:
        Location=driver.find_element_by_xpath('//div[@class="_1l939"]/div[2]/div[2]/div[2]')
        location.append(Location.text)
    except NoSuchElementException:
        location.append('-')
    try:
        Posting=driver.find_element_by_xpath('//div[@class="_1l939"]/div[3]/div[2]/div[2]')
        postingdate.append(Posting.text)
    except NoSuchElementException:
        postingdate.append('-')
        
    try:
        Price=driver.find_element_by_class_name('_3FkyT')
        price.append(Price.text)
    except NoSuchElementException:
        price.append('-')
        
        
        
        
        
        
len(name) , len(model), len(fuel),len(driven),len(automatic) ,len(owner),len(location),len(postingdate),len(price)
# Out:
# (500, 500, 500, 500, 500, 500, 500, 500, 500)

# %%
len(manufacture)
# Out:
# 20

# %%
df=pd.DataFrame({'Name': name,'Manufacture':manufacture,'Model':model,'Fuel':fuel,'Driven':driven,'Automatic':automatic,'Owner':owner,'Location':location,'Posting Date':postingdate,'Price':price})

# %%
# create excel file
file_name = 'olx.xlsx'

# %%
# save data to excel

df.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# details one by one

driver.get('https://www.olx.in/item/maruti-suzuki-swift-ldi-2014-diesel-iid-1685939081')
title= driver.find_element_by_class_name('_3FkyT')
title.text
# Out:
# '₹ 2,98,999'

# %% [markdown]
# # Car Dekho

# %%
# lets connect to driver

driver= webdriver.Chrome(r'C:\working\chromedriver.exe')
driver.maximize_window()

url='https://www.cardekho.com/used-cars+in+new-delhi'
driver.get(url)

# %%
for _ in range(100):


    driver.execute_script("window.scrollBy(0,800)")

# %%
link= driver.find_elements_by_xpath('//div[@class=" gsc_row minheight"]/div/a')

# %%
url=[]
for i in link:
    url.append(i.get_attribute('href'))

# %%
len(url)
# Out:
# 40

# %%
name=[]
manufacture=[]
model=[]
fuel=[]
driven=[]
automatic=[]
owner=[]
location=[]
postingdate=[]
price=[]


for i in url:
    driver.get(i)
    time.sleep(2)
    # Name
    try:
        title= driver.find_element_by_xpath('//div[@class="paddingBorder clearfix"]/div/h1')
        name.append(title.text.split(' ',1)[1])
        
    except NoSuchElementException:
        name.append('-')
        
    # Manufacture year 
    try:
        title= driver.find_element_by_xpath('//div[@class="paddingBorder clearfix"]/div/h1')
        manufacture.append(title.text.split(' ',1)[0])
    except NoSuchElementException:
        manufacture.append('-')
        
    # Model
    try:
        Model=driver.find_element_by_xpath('//div[@class="paddingBorder clearfix"]/div')
        model.append(Model.text.split('\n')[1])
    except NoSuchElementException:
        model.append('-')
       
    # Fuel Type
    try:
        tab=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[3]')
        fuel.append(tab.text.split('\n')[1])
    except NoSuchElementException:
        fuel.append('-')
        
    # KM Driven
    try:
        tab=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[4]')
        driven.append(tab.text.split('\n')[1])
    except NoSuchElementException:
        driven.append('-')
        
    # Automatic/ Manual
    try:
        tab=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[8]')
        automatic.append(tab.text.split('\n')[1])
    except NoSuchElementException:
        automatic.append('-')
      
    # Owner count
    try:
        Owner=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[6]')
        owner.append(Owner.text.split('\n')[1])
    except NoSuchElementException:
        owner.append('-')
      
    # Location
    try:
        Location=driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[7]')
        location.append(Location.text.split('\n')[1])
    except NoSuchElementException:
        location.append('-')
        
    # Posting
    try:
        Posting=driver.find_element_by_xpath('//div[@class="_1l939"]/div[3]/div[2]/div[2]')
        postingdate.append(Posting.text)
    except NoSuchElementException:
        postingdate.append('-')
        
    # Price
    try:
        Price=driver.find_element_by_xpath('//div[@class="paddingBorder clearfix"]/div[2]/div/div')
        price.append(Price.text.split('\n')[0])
    except NoSuchElementException:
        price.append('-')
        
        
        
        
        
        
len(name) , len(model), len(fuel),len(driven),len(automatic) ,len(owner),len(location),len(postingdate),len(price)
# Out:
# (260, 260, 260, 260, 260, 260, 260, 260, 260)

# %%
data=pd.DataFrame({'Name': name,'Manufacture':manufacture,'Model':model,'Fuel':fuel,'Driven':driven,'Automatic':automatic,'Owner':owner,'Location':location,'Posting Date':postingdate,'Price':price})

# %%
data
# Out:
#                      Name Manufacture        Model    Fuel        Driven  \
# 0            Maruti Swift        2015      VVT VXI  Petrol    43,832 Kms
# 1         Maruti Alto 800        2015          VXI  Petrol    59,500 Kms
# 2             Maruti Ciaz        2018    1.4 Sigma  Petrol    19,880 Kms
# 3             Hyundai i10        2014  Sportz 1.1L  Petrol    33,764 Kms
# 4           Renault Kiger        2021      RXT AMT  Petrol     5,799 Kms
# ..                    ...         ...          ...     ...           ...
# 255        Renault Triber        2019     RXT BSIV  Petrol    12,609 Kms
# 256         Maruti Baleno        2019        Delta  Petrol    19,282 Kms
# 257           Maruti Ciaz        2014   ZDi Option  Diesel    65,952 Kms
# 258          Maruti Swift        2014          VDI  Diesel  1,17,915 Kms
# 259  Toyota Corolla Altis        2018   1.8 VL CVT  Petrol    63,366 Kms
#
#      Automatic      Owner Location Posting Date        Price
# 0       Manual  1st Owner     DL2C            -   ₹ 4,45,000
# 1       Manual  1st Owner     HR72            -   ₹ 2,85,000
# 2       Manual  1st Owner     DL9C            -   ₹ 7,80,000
# 3       Manual  2nd Owner     HR03            -   ₹ 3,23,000
# 4    Automatic  1st Owner     DL3C            -   ₹ 8,02,000
# ..         ...        ...      ...          ...          ...
# 255     Manual  1st Owner     HR51            -   ₹ 5,45,000
# 256     Manual  1st Owner     HR26            -   ₹ 5,99,000
# 257     Manual  2nd Owner     DL1C            -   ₹ 4,63,000
# 258     Manual  1st Owner     DL2C            -   ₹ 3,26,000
# 259  Automatic  1st Owner     DL1C            -  ₹ 14,57,000
#
# [260 rows x 10 columns]

# %%
# create excel file
file = 'cardekho.xlsx'

# %%
# save data to excel

data.to_excel(file)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# details one by one

driver= webdriver.Chrome(r'C:\Users\Administrator\Data Science\WebScrapping\chromedriver.exe')
driver.get('https://www.cardekho.com/buy-used-car-details/used-Maruti-Baleno-1.2-Alpha-cars-New-Delhi_785fa298-10bb-4099-b6ec-6def9c8a1a6d.htm')

# %%
title= driver.find_element_by_xpath('//ul[@class="gsc_row detailsList"]/li[3]')
title.text.split('\n')[1]
# Out:
# 'Petrol'

# %% [markdown]
# # CAR24

# %%
# lets connect to driver

driver= webdriver.Chrome(r'C:\Users\Administrator\Data Science\WebScrapping\chromedriver.exe')
driver.maximize_window()

url='https://www.cars24.com/buy-used-car?sort=P&storeCityId=2&pinId=110001'
driver.get(url)

# %%
for _ in range(50):
    driver.execute_script("window.scrollBy(0,1080)")

# %%
link= driver.find_elements_by_xpath('//div[@class="col-4"]/a')

url=[]
for i in link:
    url.append(i.get_attribute('href'))

# %%
len(url)
# Out:
# 60

# %%
name=[]
manufacture=[]
model=[]
fuel=[]
driven=[]
automatic=[]
owner=[]
location=[]
postingdate=[]
price=[]


# Name and Manufacture
names= driver.find_elements_by_class_name('_3FpCg')

for i in names:
    manufacture.append(i.text.split(" ",1)[0])
    name.append(i.text.split(" ",1)[1])

# Model
var= driver.find_elements_by_class_name('cvakB')
for i in var:
    try:
        model.append(i.text.rsplit(' ',1)[0])
    except NoSuchElementException:
        model.append('-')
        
for i in var:
    try:
        automatic.append(i.text.rsplit(' ',1)[1])
    except NoSuchElementException:
        automatic.append('-')
    

for i in url:
    driver.get(i)
    time.sleep(2)
    
          
    # Fuel Type
    try:
        tab=driver.find_element_by_xpath('//ul[@class="_2tp8h"]/li[3]')
        fuel.append(tab.text)
    except NoSuchElementException:
        fuel.append('-')
        
    # KM Driven
    try:
        tab=driver.find_element_by_xpath('//ul[@class="_2tp8h"]/li')
        driven.append(tab.text)
    except NoSuchElementException:
        driven.append('-')
        
          
    # Owner count
    try:
        Owner=driver.find_element_by_xpath('//ul[@class="_2tp8h"]/li[5]')
        owner.append(Owner.text)
    except NoSuchElementException:
        owner.append('-')
      
    # Location
    try:
        Location=driver.find_element_by_xpath('//ul[@class="_2tp8h"]/li[7]')
        location.append(Location.text)
    except NoSuchElementException:
        location.append('-')
        
    # Posting
    try:
        Posting=driver.find_element_by_xpath('//div[@class="_1l939"]/div[3]/div[2]/div[2]')
        postingdate.append(Posting.text)
    except NoSuchElementException:
        postingdate.append('-')
        
    # Price
    try:
        Price=driver.find_element_by_xpath('//ul[@class="_10Etm"]/li/span[2]')
        price.append(Price.text)
    except NoSuchElementException:
        price.append('-')
        
        
        
        
        
        
len(name) , len(model), len(fuel),len(driven),len(automatic) ,len(owner),len(location),len(postingdate),len(price)
# Out:
# (60, 60, 60, 60, 60, 60, 60, 60, 60)

# %%
len(manufacture)
# Out:
# 60

# %%
car24=pd.DataFrame({'Name': name,'Manufacture':manufacture,'Model':model,'Fuel':fuel,'Driven':driven,'Automatic':automatic,'Owner':owner,'Location':location,'Posting Date':postingdate,'Price':price})
car24
# Out:
#                      Name Manufacture                   Model    Fuel  \
# 0           Hyundai Verna        2019         1.6 SX VTVT (O)  Petrol
# 1              KIA SELTOS        2020     HTK PLUS 1.5 PETROL  Petrol
# 2            Renault Kwid        2016                     RXT  Petrol
# 3   Mercedes Benz C Class        2014        C 200 AVANTGARDE  Petrol
# 4              KIA SELTOS        2020           HTX AT PETROL  Petrol
# 5           Maruti Baleno        2018           SIGMA 1.2 K12  Petrol
# 6      Maruti Wagon R 1.0        2011                     VXI  Petrol
# 7             Hyundai i10        2011        MAGNA 1.2 KAPPA2  Petrol
# 8               Jaguar XF        2013              2.2 DIESEL  Diesel
# 9         Maruti Alto 800        2013                     VXI  Petrol
# 10            Hyundai i10        2009            ERA 1.1 IRDE  Petrol
# 11        Maruti Alto K10        2011                     VXI  Petrol
# 12           Maruti Swift        2019                     VXI  Petrol
# 13           Jeep Compass        2019             2.0 LIMITED  Diesel
# 14          Hyundai VENUE        2021          S MT 1.2 KAPPA  Petrol
# 15         MG HECTOR PLUS        2020     SHARP HYBRID PETROL  Petrol
# 16           Renault Kwid        2018                     RXL  Petrol
# 17      Hyundai Elite i20        2019     1.2 MAGNA PLUS VTVT  Petrol
# 18            Hyundai i10        2013    SPORTZ 1.2 AT KAPPA2  Petrol
# 19           Nissan Micra        2014               XE DIESEL  Diesel
# 20             Honda City        2016            SV MT PETROL  Petrol
# 21            Hyundai i10        2014         MAGNA 1.1 IRDE2  Petrol
# 22          Renault Kiger        2021             RXT 1.0 AMT  Petrol
# 23          Hyundai VENUE        2021          1.5 SX CRDI MT  Diesel
# 24            Maruti Ciaz        2021  ALPHA 1.5 MT VTVT SHVS  Petrol
# 25            Skoda Rapid        2020          ACTIVE 1.0 TSI  Petrol
# 26     Maruti Wagon R 1.0        2010                     LXI  Petrol
# 27             Honda City        2014           VX CVT PETROL  Petrol
# 28        Toyota Fortuner        2015              3.0 AT 4X2  Diesel
# 29            Hyundai i10        2011       SPORTZ 1.2 KAPPA2  Petrol
# 30            Hyundai i20        2010             MAGNA O 1.2  Petrol
# 31      Hyundai Grand i10        2020          MAGNA 1.2 VTVT  Petrol
# 32             Honda City        2010             S MT PETROL  Petrol
# 33  Mercedes Benz E Class        2013    E 250 CDI AVANTGARDE  Diesel
# 34             Honda City        2014            VX MT PETROL  Petrol
# 35   Toyota URBAN CRUISER        2021                     MID  Petrol
# 36          Hyundai VENUE        2021    1.0L Turbo GDI SX MT  Petrol
# 37         Datsun Redi Go        2018                 T(O) AT  Petrol
# 38           Renault Kwid        2021     1.0 CLIMBER OPT AMT  Petrol
# 39        Maruti Alto K10        2011                     VXI  Petrol
# 40            Hyundai i20        2010             MAGNA O 1.2  Petrol
# 41           Renault Kwid        2018                     RXL  Petrol
# 42   Maruti Vitara Brezza        2021                     VXI  Petrol
# 43           Renault Kwid        2021             1.0 RXT Opt  Petrol
# 44             Honda City        2020            VX MT PETROL  Petrol
# 45         Renault Duster        2021           RXS 106 PS MT  Petrol
# 46            Hyundai i20        2013            ERA 1.4 CRDI  Diesel
# 47              Honda CRV        2015              2.0 2WD AT  Petrol
# 48            Maruti Ciaz        2021  ALPHA 1.5 MT VTVT SHVS  Petrol
# 49      Hyundai Elite i20        2017              SPORTZ 1.2  Petrol
# 50      Hyundai Grand i10        2017  SPORTZ (O) 1.2 AT VTVT  Petrol
# 51              MG HECTOR        2019        SHARP DCT PETROL  Petrol
# 52          Hyundai Creta        2019            1.6 E + VTVT  Petrol
# 53      Hyundai Grand i10        2016          MAGNA 1.2 VTVT  Petrol
# 54             Tata Tiago        2021          XTA 1.2 PETROL  Petrol
# 55   Maruti Vitara Brezza        2020               ZDI + AMT  Diesel
# 56          Toyota Innova        2014      2.5 VX 8 STR BS IV  Diesel
# 57             Honda Jazz        2018               1.2 SV MT  Petrol
# 58   Mahindra KUV 100 NXT        2017                K2 6 STR  Petrol
# 59          Mahindra Thar        2021   LX 4WD AT CONVERTIBLE  Petrol
#
#        Driven  Automatic      Owner Location Posting Date        Price
# 0   80,631 km     Manual  1st Owner    HR-26            -   ₹ 9,81,699
# 1   12,981 km     Manual  2nd Owner    HR-26            -  ₹ 11,55,299
# 2   22,388 km     Manual  1st Owner    DL-1C            -   ₹ 2,79,799
# 3   36,806 km  Automatic  1st Owner    UP-16            -  ₹ 21,33,299
# 4   21,784 km  Automatic  2nd Owner    HR-26            -  ₹ 14,29,999
# 5   20,330 km     Manual  1st Owner    DL-6C            -   ₹ 5,24,799
# 6   54,723 km     Manual  1st Owner    DL-8C            -   ₹ 2,66,099
# 7   47,547 km     Manual  1st Owner    DL-7C            -   ₹ 1,90,999
# 8   28,289 km  Automatic  2nd Owner    DL-6C            -  ₹ 16,45,899
# 9   40,369 km     Manual  1st Owner    UP-16            -   ₹ 2,42,399
# 10  44,319 km     Manual  1st Owner    UP-16            -   ₹ 2,04,199
# 11  23,277 km     Manual  1st Owner    DL-8C            -   ₹ 2,21,199
# 12  32,251 km     Manual  1st Owner    UP-37            -   ₹ 5,60,399
# 13  46,400 km     Manual  1st Owner    HR-26            -  ₹ 20,19,999
# 14  21,490 km     Manual  1st Owner    UP-14            -   ₹ 8,21,399
# 15   2,775 km     Manual  1st Owner    UP-14            -  ₹ 18,37,899
# 16  22,505 km     Manual  2nd Owner    HR-79            -   ₹ 3,22,499
# 17  22,638 km     Manual  2nd Owner    DL-10            -   ₹ 6,17,899
# 18  28,843 km  Automatic  1st Owner    DL-3C            -   ₹ 3,53,399
# 19  63,433 km     Manual  1st Owner    DL-1C            -   ₹ 2,75,299
# 20  45,246 km     Manual  1st Owner    DL-9C            -   ₹ 6,64,499
# 21  12,511 km     Manual  1st Owner    DL-3C            -   ₹ 3,40,499
# 22   6,344 km  Automatic  1st Owner    DL-8C            -   ₹ 8,21,699
# 23   2,213 km     Manual  1st Owner    DL-5C            -  ₹ 12,13,499
# 24   9,370 km     Manual  1st Owner    UP-14            -  ₹ 12,13,599
# 25  11,399 km     Manual  1st Owner    UP-14            -   ₹ 7,83,699
# 26  48,915 km     Manual  2nd Owner    DL-2C            -   ₹ 2,44,099
# 27  51,105 km  Automatic  1st Owner    DL-2C            -   ₹ 7,11,899
# 28  90,086 km  Automatic  2nd Owner    HR-26            -  ₹ 15,77,799
# 29  66,782 km     Manual  2nd Owner    DL-4C            -   ₹ 2,88,599
# 30  42,422 km     Manual  2nd Owner    DL-4C            -   ₹ 2,70,399
# 31  13,223 km     Manual  2nd Owner    DL-4C            -   ₹ 5,92,299
# 32  34,566 km     Manual  1st Owner    DL-4C            -   ₹ 4,23,899
# 33  42,881 km  Automatic  2nd Owner    DL-1C            -  ₹ 14,55,599
# 34  54,517 km     Manual  1st Owner    DL-2C            -   ₹ 6,49,499
# 35  11,828 km         MT  1st Owner    HR-26            -   ₹ 9,25,899
# 36  29,645 km     Manual  1st Owner    HR-51            -   ₹ 9,90,499
# 37   4,555 km  Automatic  1st Owner    DL-8C            -   ₹ 3,86,699
# 38   7,760 km  Automatic  1st Owner    UP-14            -   ₹ 5,56,499
# 39  26,475 km     Manual  1st Owner    DL-9C            -   ₹ 2,35,499
# 40  60,774 km     Manual  1st Owner    DL-1C            -   ₹ 2,98,999
# 41  20,830 km     Manual  2nd Owner    DL-3C            -   ₹ 3,18,799
# 42   5,287 km     Manual  1st Owner    DL-6C            -   ₹ 9,10,199
# 43   6,962 km     Manual  1st Owner    UP-14            -   ₹ 5,00,199
# 44   7,212 km     Manual  1st Owner    HR-26            -  ₹ 13,10,699
# 45   2,572 km     Manual  1st Owner    HR-29            -   ₹ 9,13,999
# 46  29,974 km     Manual  1st Owner    DL-10            -   ₹ 3,06,299
# 47  73,937 km  Automatic  1st Owner    DL-9C            -  ₹ 12,68,899
# 48   4,536 km     Manual  1st Owner    HR-98            -  ₹ 11,84,499
# 49  30,697 km     Manual  3rd Owner    DL-8C            -   ₹ 5,22,799
# 50  12,855 km  Automatic  1st Owner    DL-12            -   ₹ 6,22,699
# 51   8,717 km  Automatic  1st Owner    DL-10            -  ₹ 18,12,799
# 52  40,193 km     Manual  1st Owner    HR-26            -   ₹ 9,17,099
# 53  45,277 km     Manual  1st Owner    HR-26            -   ₹ 4,28,999
# 54   6,568 km  Automatic  1st Owner    DL-5C            -   ₹ 7,10,599
# 55  18,191 km  Automatic  1st Owner    DL-2C            -  ₹ 11,04,299
# 56  82,295 km     Manual  1st Owner    HR-55            -   ₹ 9,64,299
# 57  23,733 km     Manual  2nd Owner    DL-8C            -   ₹ 6,12,599
# 58   9,835 km     Manual  1st Owner    DL-8C            -   ₹ 3,88,399
# 59   3,120 km  Automatic  1st Owner    HR-26            -  ₹ 18,02,499

# %%
filename='car24.xlsx'

# %%
car24.to_excel(filename)
